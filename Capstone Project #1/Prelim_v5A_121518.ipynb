# %%
import nltk
import pandas as pd
import numpy as np
from nltk import sent_tokenize, word_tokenize
from nltk.tokenize import WordPunctTokenizer
from nltk.tokenize import TreebankWordTokenizer
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from collections import Counter

# %%
wpt = WordPunctTokenizer()
tbwt = TreebankWordTokenizer()
p_stem = PorterStemmer()
w_lem = WordNetLemmatizer()

# %%
# Load training dataset to dataframe 'df'
df = pd.read_csv('train.csv')

# %%
# Create dataframe with only neutral comments (not labeled for any of the toxic category)

df['total']= df.toxic + df.severe_toxic + df.obscene + df.threat + df.insult + df.identity_hate 
df_neutral = df[df.total==0]

# %%
# Based on dataframe with only neutral comments, generate a list of unique neutral words (5-word)

neutral_list_5 = []
    
for num in range(len(df_neutral.comment_text)):

    place_holder = []

    for word in wpt.tokenize(df_neutral.comment_text.iloc[num]):

        word_low = word.lower()
        place_holder.append(word_low)
        
        if len(place_holder) == 5:
            phrase = " ".join(place_holder)  
            
            neutral_list_5.append(phrase)            

            del place_holder[0]  

neutral_list_5_unique = []

for pair in list(Counter(neutral_list_5).most_common(1000)):
    neutral_list_5_unique.append(pair[0])

# %%
# Based on dataframe with only neutral comments, generate a list of unique neutral words (6-word)

neutral_list_6 = []
    
for num in range(len(df_neutral.comment_text)):

    place_holder = []

    for word in wpt.tokenize(df_neutral.comment_text.iloc[num]):

        word_low = word.lower()
        place_holder.append(word_low)
        
        if len(place_holder) == 6:
            phrase = " ".join(place_holder)  
            
            neutral_list_6.append(phrase)            

            del place_holder[0]  

neutral_list_6_unique = []

for pair in list(Counter(neutral_list_6).most_common(1000)):
    neutral_list_6_unique.append(pair[0])

# %%
# Create dataframes containing toxic comments based on each type of labeled toxic category. 
# Comments labeled/categorized as multiple toxic categories are not accounted for at this point.
df_toxic = df[df.toxic == 1]
df_severe_toxic = df[df.severe_toxic == 1]
df_obscene = df[df.obscene == 1]
df_threat = df[df.threat == 1]
df_insult = df[df.insult == 1]
df_identity_hate = df[df.identity_hate == 1]

# %%
# Approach --- for each toxic category, the comments would contain both toxic words + neutral words. By removing
# the neutral words generated by neutral comments, the toxic words would remain.
# Example, for each toxic category, [toxic words + neutral words] - [neutral words] = toxic words

# %%
# Toxic words can be 1 word (single-word) or phrasese (2- , 3-, 4-words)

# %%
# Function to generate toxic words by 5-word and count the frequencies.

def word_count_5(dataframe,name):
    
    global_list_cnt = []

    for num in range(len(dataframe.comment_text)):

        place_holder = []
        local_list_cnt = []

        for word in wpt.tokenize(dataframe.comment_text.iloc[num]):

            word_low = word.lower()

            #place_holder.append(p_stem.stem(word_low))
            place_holder.append(word_low)

            if len(place_holder) == 5:
                phrase = " ".join(place_holder)  

                # Taking out the neutral 5-word phrase
                if phrase not in neutral_list_5_unique:

                    if phrase not in local_list_cnt:
                        local_list_cnt.append(phrase)

                    del place_holder[0]     

        global_list_cnt.extend(local_list_cnt)

    list_cnt = Counter(global_list_cnt)
    
    df_wcnt = pd.DataFrame.from_dict(dict(list_cnt),orient='index',columns=['count'])
    df_wcnt['% of Total'] = round(df_wcnt['count'] / df_wcnt['count'].sum() * 100,2)

    rank = []
    for num in range(20):
        rank.append(num+1)    
   
    df_wcnt = df_wcnt.sort_values('count',ascending=False).head(20).reset_index()
    df_wcnt['rank']=rank
    df_wcnt_ranked = df_wcnt.set_index('rank')
    df_wcnt_ranked = df_wcnt_ranked.rename(columns={"index": name})    
    
    return (df_wcnt_ranked)

# %%
# Function to generate toxic words by 6-word and count the frequencies.

def word_count_6(dataframe,name):
    
    global_list_cnt = []

    for num in range(len(dataframe.comment_text)):

        place_holder = []
        local_list_cnt = []

        for word in wpt.tokenize(dataframe.comment_text.iloc[num]):

            word_low = word.lower()

            #place_holder.append(p_stem.stem(word_low))
            place_holder.append(word_low)

            if len(place_holder) == 6:
                phrase = " ".join(place_holder)  

                # Taking out the neutral 6-word phrase
                if phrase not in neutral_list_6_unique:

                    if phrase not in local_list_cnt:
                        local_list_cnt.append(phrase)

                    del place_holder[0]     

        global_list_cnt.extend(local_list_cnt)

    list_cnt = Counter(global_list_cnt)
    
    df_wcnt = pd.DataFrame.from_dict(dict(list_cnt),orient='index',columns=['count'])
    df_wcnt['% of Total'] = round(df_wcnt['count'] / df_wcnt['count'].sum() * 100,2)

    rank = []
    for num in range(20):
        rank.append(num+1)    
   
    df_wcnt = df_wcnt.sort_values('count',ascending=False).head(20).reset_index()
    df_wcnt['rank']=rank
    df_wcnt_ranked = df_wcnt.set_index('rank')
    df_wcnt_ranked = df_wcnt_ranked.rename(columns={"index": name})    
    
    return (df_wcnt_ranked)

# %%
# Execute function to generate toxic words by 5-word count
df_toxic_5wcnt = word_count_5(df_toxic,'toxic')
df_severe_toxic_5wcnt = word_count_5(df_severe_toxic,'severe_toxic')
df_obscene_5wcnt = word_count_5(df_obscene,'obscene')
df_threat_5wcnt = word_count_5(df_threat,'threat')
df_insult_5wcnt = word_count_5(df_insult,'insult')
df_identity_hate_5wcnt = word_count_5(df_identity_hate,'identity_hate')

# %%
# Execute function to generate toxic words by 6-word count
df_toxic_6wcnt = word_count_6(df_toxic,'toxic')
df_severe_toxic_6wcnt = word_count_6(df_severe_toxic,'severe_toxic')
df_obscene_6wcnt = word_count_6(df_obscene,'obscene')
df_threat_6wcnt = word_count_6(df_threat,'threat')
df_insult_6wcnt = word_count_6(df_insult,'insult')
df_identity_hate_6wcnt = word_count_6(df_identity_hate,'identity_hate')

# %%
# Combine the results of all six toxic categories in one table
master_list_5wc = pd.concat([df_toxic_5wcnt, df_severe_toxic_5wcnt,df_obscene_5wcnt,df_threat_5wcnt,df_insult_5wcnt,df_identity_hate_5wcnt],axis=1)
master_list_6wc = pd.concat([df_toxic_6wcnt, df_severe_toxic_6wcnt,df_obscene_6wcnt,df_threat_6wcnt,df_insult_6wcnt,df_identity_hate_6wcnt],axis=1)

# %%
# Results of toxic word count by 5-word
master_list_5wc
# Out:
#                       toxic  count  % of Total  \
# rank
# 1            don ' t give a     53        0.01
# 2        you ' re a fucking     49        0.01
# 3      do you think you are     49        0.01
# 4              . you ' re a     45        0.01
# 5              , you ' re a     42        0.01
# 6             . why don ' t     39        0.01
# 7             , why don ' t     38        0.01
# 8        you son of a bitch     33        0.01
# 9            i don ' t give     32        0.01
# 10            , you don ' t     30        0.01
# 11        you ' re an idiot     30        0.01
# 12             don ' t be a     28        0.00
# 13            . you can ' t     27        0.00
# 14           aren ' t you ?     23        0.00
# 15           , aren ' t you     22        0.00
# 16            . don ' t you     21        0.00
# 17    what the fuck are you     21        0.00
# 18     who do you think you     21        0.00
# 19            , i ' m going     20        0.00
# 20     who the hell are you     20        0.00
#
#                          severe_toxic  count  % of Total  \
# rank
# 1                  you son of a bitch     17        0.04
# 2                  you ' re a fucking     15        0.04
# 3                      don ' t give a      8        0.02
# 4                    son of a bitch ,      7        0.02
# 5                do you think you are      7        0.02
# 6           motherfucker , go fuck ur      6        0.01
# 7            , motherfucker , go fuck      6        0.01
# 8              fuck ur mothers cunt ,      6        0.01
# 9             go fuck ur mothers cunt      6        0.01
# 10               , go fuck ur mothers      6        0.01
# 11                    . i am going to      6        0.01
# 12     bitch , asshole , motherfucker      6        0.01
# 13        asshole , motherfucker , go      6        0.01
# 14         , asshole , motherfucker ,      6        0.01
# 15            mothers cunt , trade ur      6        0.01
# 16               cunt , trade ur wife      6        0.01
# 17             , trade ur wife sister      6        0.01
# 18            ur mothers cunt , trade      6        0.01
# 19    mothjer fucker cocksucker ! you      5        0.01
# 20                     . get a life ,      5        0.01
#
#                     obscene  count  % of Total  \
# rank
# 1        you ' re a fucking     46        0.02
# 2            don ' t give a     36        0.01
# 3      do you think you are     34        0.01
# 4        you son of a bitch     33        0.01
# 5              , you ' re a     28        0.01
# 6              . you ' re a     28        0.01
# 7             , why don ' t     27        0.01
# 8            i don ' t give     25        0.01
# 9             . why don ' t     24        0.01
# 10             don ' t be a     21        0.01
# 11    what the fuck are you     20        0.01
# 12    the fuck do you think     19        0.01
# 13      you piece of shit .     16        0.01
# 14        you ' re an idiot     16        0.01
# 15     shut the fuck up you     14        0.00
# 16    fuck do you think you     14        0.00
# 17            , you don ' t     13        0.00
# 18            , you can ' t     13        0.00
# 19         son of a bitch ,     12        0.00
# 20      who the fuck do you     12        0.00
#
#                                threat  count  % of Total  \
# rank
# 1                  i am going to kill      7        0.04
# 2                am going to kill you      7        0.04
# 3               i know where you live      6        0.04
# 4                   i hope you die in      6        0.04
# 5                  and i hope you die      6        0.04
# 6               in the head and laugh      5        0.03
# 7               am going to shoot you      5        0.03
# 8              come to your house and      5        0.03
# 9               going to shoot you in      5        0.03
# 10                to shoot you in the      5        0.03
# 11                    i ' ll kill you      5        0.03
# 12              shoot you in the head      5        0.03
# 13                you in the head and      5        0.03
# 14               im going to kill you      5        0.03
# 15              the head and laugh as      5        0.03
# 16                    , i am going to      5        0.03
# 17                    . i am going to      5        0.03
# 18    brains splatter onto the ground      5        0.03
# 19      your brains splatter onto the      5        0.03
# 20       as your brains splatter onto      5        0.03
#
#                      insult  count  % of Total  \
# rank
# 1        you ' re a fucking     43        0.02
# 2              , you ' re a     33        0.01
# 3        you son of a bitch     33        0.01
# 4              . you ' re a     30        0.01
# 5      do you think you are     27        0.01
# 6         you ' re an idiot     26        0.01
# 7             . why don ' t     25        0.01
# 8            don ' t give a     24        0.01
# 9             , why don ' t     20        0.01
# 10             don ' t be a     18        0.01
# 11            , you don ' t     16        0.01
# 12           i don ' t give     16        0.01
# 13           aren ' t you ?     15        0.01
# 14    the fuck do you think     15        0.01
# 15            . you can ' t     15        0.01
# 16          ' re an idiot .     14        0.01
# 17           , aren ' t you     13        0.00
# 18     shut the fuck up you     13        0.00
# 19            , you ' re an     13        0.00
# 20      you piece of shit .     13        0.00
#
#                            identity_hate  count  % of Total
# rank
# 1                            . 28 . 54 .      6        0.01
# 2                           28 . 54 . 73      6        0.01
# 3                          . why don ' t      5        0.01
# 4                     you ' re a fucking      5        0.01
# 5                           , you ' re a      5        0.01
# 6     nigger nigger nigger nigger nigger      5        0.01
# 7                              . i ' m a      4        0.01
# 8                     you son of a bitch      4        0.01
# 9                          , why don ' t      4        0.01
# 10            you are german cock sucker      4        0.01
# 11              you can go fuck yourself      4        0.01
# 12                         211 . 28 . 54      4        0.01
# 13                  shut the fuck up you      4        0.01
# 14                     i can ' t believe      4        0.01
# 15              servant , with money and      3        0.01
# 16             poor servant , with money      3        0.01
# 17             , with money and property      3        0.01
# 18                    who must wait as a      3        0.01
# 19                 a poor servant , with      3        0.01
# 20                   as a poor servant ,      3        0.01

# %%
# Results of toxic word count by 6-word
master_list_6wc
# Out:
#                             toxic  count  % of Total  \
# rank
# 1                i don ' t give a     68        0.01
# 2               , why don ' t you     43        0.01
# 3               . why don ' t you     41        0.01
# 4             don ' t give a shit     35        0.01
# 5              why don ' t you go     24        0.00
# 6                , i ' m going to     22        0.00
# 7                . i don ' t care     21        0.00
# 8             don ' t give a fuck     20        0.00
# 9        who do you think you are     20        0.00
# 10         do you think you are ?     18        0.00
# 11               , i don ' t care     18        0.00
# 12           why don ' t you just     17        0.00
# 13               , aren ' t you ?     17        0.00
# 14            don ' t give a damn     15        0.00
# 15               . i don ' t give     15        0.00
# 16      the fuck do you think you     14        0.00
# 17            you ' re an idiot .     14        0.00
# 18               i don ' t care .     13        0.00
# 19             . you don ' t know     13        0.00
# 20    just wanted to let you know     12        0.00
#
#                              severe_toxic  count  % of Total  \
# rank
# 1                        i don ' t give a     12        0.03
# 2       motherfucker , go fuck ur mothers      6        0.01
# 3        bitch , asshole , motherfucker ,      6        0.01
# 4             , motherfucker , go fuck ur      6        0.01
# 5        asshole , motherfucker , go fuck      6        0.01
# 6            fuck ur mothers cunt , trade      6        0.01
# 7              ur mothers cunt , trade ur      6        0.01
# 8            mothers cunt , trade ur wife      6        0.01
# 9               , go fuck ur mothers cunt      6        0.01
# 10          , asshole , motherfucker , go      6        0.01
# 11            cunt , trade ur wife sister      6        0.01
# 12              go fuck ur mothers cunt ,      6        0.01
# 13                    don ' t give a shit      5        0.01
# 14                      , why don ' t you      5        0.01
# 15             ! you are a mothjer fucker      5        0.01
# 16         cocksucker ! you are a mothjer      5        0.01
# 17          fucker cocksucker ! you are a      5        0.01
# 18    you are a mothjer fucker cocksucker      5        0.01
# 19    mothjer fucker cocksucker ! you are      5        0.01
# 20      are a mothjer fucker cocksucker !      5        0.01
#
#                              obscene  count  % of Total  \
# rank
# 1                   i don ' t give a     56        0.02
# 2                don ' t give a shit     30        0.01
# 3                  , why don ' t you     30        0.01
# 4                  . why don ' t you     26        0.01
# 5                don ' t give a fuck     19        0.01
# 6                 why don ' t you go     14        0.00
# 7                   . i don ' t give     14        0.00
# 8          the fuck do you think you     14        0.00
# 9                  don ' t be a dick     13        0.00
# 10         fuck do you think you are     12        0.00
# 11         who the fuck do you think     12        0.00
# 12            do you think you are ?     12        0.00
# 13          who do you think you are     11        0.00
# 14              why don ' t you just     10        0.00
# 15     what the fuck is your problem     10        0.00
# 16              , you ' re a fucking     10        0.00
# 17          you ' re a fucking idiot     10        0.00
# 18                  , i ' m going to     10        0.00
# 19                 ' t give a shit .      9        0.00
# 20    the fuck are you talking about      9        0.00
#
#                                     threat  count  % of Total  \
# rank
# 1                   i am going to kill you      6        0.03
# 2                going to shoot you in the      5        0.03
# 3     your brains splatter onto the ground      5        0.03
# 4         as your brains splatter onto the      5        0.03
# 5       laugh as your brains splatter onto      5        0.03
# 6        and laugh as your brains splatter      5        0.03
# 7            head and laugh as your brains      5        0.03
# 8               the head and laugh as your      5        0.03
# 9                 in the head and laugh as      5        0.03
# 10               shoot you in the head and      5        0.03
# 11                to shoot you in the head      5        0.03
# 12               you in the head and laugh      5        0.03
# 13                am going to shoot you in      5        0.03
# 14                     i ' m going to kill      5        0.03
# 15            will die you pathetic fool !      4        0.02
# 16                i will hunt you down and      4        0.02
# 17                 you don ' t respect the      4        0.02
# 18                  forever ! if you don '      4        0.02
# 19                        ! if you don ' t      4        0.02
# 20          ' t respect the supertr0ll you      4        0.02
#
#                              insult  count  % of Total  \
# rank
# 1                  i don ' t give a     33        0.01
# 2                 . why don ' t you     26        0.01
# 3                 , why don ' t you     23        0.01
# 4                why don ' t you go     16        0.01
# 5               don ' t give a shit     15        0.01
# 6               don ' t give a fuck     14        0.00
# 7               you ' re an idiot .     14        0.00
# 8              why don ' t you just     12        0.00
# 9                  , aren ' t you ?     11        0.00
# 10        the fuck do you think you     10        0.00
# 11         you ' re a fucking idiot     10        0.00
# 12             , you ' re a fucking     10        0.00
# 13                 , i ' m going to     10        0.00
# 14         who do you think you are     10        0.00
# 15                don ' t be a dick      9        0.00
# 16        who the fuck do you think      9        0.00
# 17    what the fuck is your problem      9        0.00
# 18               . you don ' t know      8        0.00
# 19              i don ' t care what      8        0.00
# 20                i don ' t have to      8        0.00
#
#                                   identity_hate  count  % of Total
# rank
# 1                             . why don ' t you      6        0.01
# 2                                . 28 . 54 . 73      6        0.01
# 3     nigger nigger nigger nigger nigger nigger      5        0.01
# 4                            why don ' t you go      5        0.01
# 5                               211 . 28 . 54 .      4        0.01
# 6                             , why don ' t you      4        0.01
# 7                       have ! i wish they were      3        0.01
# 8          cock sucker and fucker mother fucker      3        0.01
# 9                   were in hell with the other      3        0.01
# 10                   they were in hell with the      3        0.01
# 11                  wish they were in hell with      3        0.01
# 12                     i wish they were in hell      3        0.01
# 13                        ! i wish they were in      3        0.01
# 14                   everything i have ! i wish      3        0.01
# 15                         i have ! i wish they      3        0.01
# 16             property and everything i have !      3        0.01
# 17           and property and everything i have      3        0.01
# 18          money and property and everything i      3        0.01
# 19       with money and property and everything      3        0.01
# 20                , with money and property and      3        0.01
